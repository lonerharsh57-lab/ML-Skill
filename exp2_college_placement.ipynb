# %% [markdown]
# # EDA: College Student Placement Factors Dataset
# Dataset: https://www.kaggle.com/datasets/sahilislam007/college-student-placement-factors-dataset
#
# **Note:** download `college_student_placement_dataset.csv` from the link above (Kaggle > Download)
# and place it in the same folder as this notebook before running, or update the filename in the cell below.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

sns.set_style("whitegrid")   # optional: gives cleaner-looking charts

# %%
# Update the filename below to match the CSV you downloaded from Kaggle
df = pd.read_csv("college_student_placement_dataset.csv")
df.head()

# %%
# Inspect column names first -- Kaggle datasets sometimes tweak naming/casing between versions.
# Adjust the list below to match df.columns exactly.
df.columns.tolist()

# %%
num_cols = ['IQ', 'CGPA', 'Prev_Sem_Result', 'Academic_Performance',
            'Communication_Skills', 'Projects_Completed']

# %%
fig1 = plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap="viridis", yticklabels=False)
plt.title("Missingness Heatmap - College Student Placement Dataset")
plt.xlabel("Columns")
plt.tight_layout()
plt.show()

# %%
fig2, axes = plt.subplots(2, 3, figsize=(15, 8))

for i, col in enumerate(num_cols):
    row, colpos = divmod(i, 3)
    sns.histplot(df[col].dropna(), bins=30, kde=True,
                 ax=axes[row, colpos], color='steelblue')
    axes[row, colpos].set_title(f'Distribution of {col}')

plt.tight_layout()
plt.show()

# %%
fig3, axes5 = plt.subplots(2, 3, figsize=(15, 8))

for i, col in enumerate(num_cols):
    row, colpos = divmod(i, 3)
    sns.boxplot(y=df[col], ax=axes5[row, colpos], color='lightcoral')
    axes5[row, colpos].set_title(f'Boxplot of {col}')

plt.tight_layout()
plt.show()

# %%
fig4 = plt.figure(figsize=(10, 8))

numeric_df = df.select_dtypes(include=['int64', 'float64'])
corr_matrix = numeric_df.corr()

sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm',
            square=True, linewidths=0.5)
plt.title('Correlation Heatmap - Numerical Features')
plt.tight_layout()
plt.show()

# %%
# Placement outcome breakdown (target column may be named 'Placement' or 'Placed' -- check df.columns above)
sns.countplot(x='Placement', data=df, palette='pastel')
plt.title('Placement Outcome Counts')
plt.tight_layout()
plt.show()
